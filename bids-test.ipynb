# %%
from bids.grabbids import BIDSLayout
layout = BIDSLayout('/scratch/PSB6351_2017/ds008_R2.0.0/')

# %%
layout.get_types()
# Out:
# ['bold',
#  'events',
#  'inplaneT2',
#  'mask',
#  'outliers',
#  'roi',
#  'sub-01',
#  'sub-02',
#  'sub-03',
#  'sub-04',
#  'sub-05',
#  'sub-06',
#  'sub-07',
#  'sub-09',
#  'sub-10',
#  'sub-11',
#  'sub-12',
#  'sub-13',
#  'sub-14',
#  'sub-15',
#  'T1w',
#  'tempfilt']

# %%
def get_niftis(subject_id, data_dir):
    # Remember that all the necesary imports need to be INSIDE the function for the Function Interface to work!
    from bids.grabbids import BIDSLayout
    
    layout = BIDSLayout(data_dir)
    
    bolds = [f.filename for f in layout.get(subject=subject_id, type='bold', extensions=['nii', 'nii.gz'])]
    
    return bolds
# Out:
# [File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/norm_anat/sub-01/anat2targ_xfm/_subject_id_sub-01/output_Composite.h5', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/norm_anat/sub-01/targ2anat_xfm/_subject_id_sub-01/output_InverseComposite.h5', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/norm_anat/sub-01/warped_image/_subject_id_sub-01/output_warped_image.nii.gz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/anat_masks/sub-01/masks/_subject_id_sub-01/_fs_anatmask_xfm0/lft_hpc_warped.nii.gz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/anat_masks/sub-01/masks/_subject_id_sub-01/_fs_anatmask_xfm1/lft_amy_warped.nii.gz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/anat_masks/sub-01/masks/_subject_id_sub-01/_fs_anatmask_xfm2/precuneus_warped.nii.gz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/anat_masks/sub-01/masks/_subject_id_sub-01/wb_warped.nii.gz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art0/art.corr_sub-01_task-stopsignal_run-01_bold_outliers.txt', type='outliers', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art0/disp.corr_sub-01_task-stopsignal_run-01_bold.nii.gz', type='bold', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art0/norm.corr_sub-01_task-stopsignal_run-01_bold.txt', type='bold', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art1/art.corr_sub-01_task-stopsignal_run-02_bold_outliers.txt', type='outliers', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art1/disp.corr_sub-01_task-stopsignal_run-02_bold.nii.gz', type='bold', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art1/norm.corr_sub-01_task-stopsignal_run-02_bold.txt', type='bold', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art2/art.corr_sub-01_task-stopsignal_run-03_bold_outliers.txt', type='outliers', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art2/disp.corr_sub-01_task-stopsignal_run-03_bold.nii.gz', type='bold', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/art/_art2/norm.corr_sub-01_task-stopsignal_run-03_bold.txt', type='bold', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/bbreg/sub-01_task-stopsignal_run-01_bold_roi_bbreg_sub-01.dat', type='sub-01', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/bbreg/sub-01_task-stopsignal_run-01_bold_roi_bbreg_sub-01.dat.mincost', type='sub-01', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/bbreg/sub-01_task-stopsignal_run-01_bold_roi_bbreg_sub-01.mat', type='sub-01', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/realigned/corr_sub-01_task-stopsignal_run-01_bold.nii.gz', type='bold', task='stopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/realigned/corr_sub-01_task-stopsignal_run-02_bold.nii.gz', type='bold', task='stopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/realigned/corr_sub-01_task-stopsignal_run-03_bold.nii.gz', type='bold', task='stopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_fullspectrum/_maskfunc20/3dFWHMx.1D', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_fullspectrum/_maskfunc20/corr_sub-01_task-stopsignal_run-01_bold_bet_smooth_mask.nii.gz', type='mask', task='stopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_fullspectrum/_maskfunc21/corr_sub-01_task-stopsignal_run-02_bold_bet_smooth_mask.nii.gz', type='mask', task='stopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_fullspectrum/_maskfunc22/corr_sub-01_task-stopsignal_run-03_bold_bet_smooth_mask.nii.gz', type='mask', task='stopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_highpassed/_bandpass0/corr_sub-01_task-stopsignal_run-01_bold_bet_smooth_mask_tempfilt.nii.gz', type='tempfilt', task='stopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_highpassed/_bandpass1/corr_sub-01_task-stopsignal_run-02_bold_bet_smooth_mask_tempfilt.nii.gz', type='tempfilt', task='stopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/func/smoothed_highpassed/_bandpass2/corr_sub-01_task-stopsignal_run-03_bold_bet_smooth_mask_tempfilt.nii.gz', type='tempfilt', task='stopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-01_bold.nii.gz_rot.png', type='bold', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-01_bold.nii.gz_trans.png', type='bold', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-02_bold.nii.gz_rot.png', type='bold', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-02_bold.nii.gz_trans.png', type='bold', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-03_bold.nii.gz_rot.png', type='bold', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/plots/sub-01_task-stopsignal_run-03_bold.nii.gz_trans.png', type='bold', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/sub-01_task-stopsignal_run-01_bold.nii.gz.par', type='bold', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/sub-01_task-stopsignal_run-02_bold.nii.gz.par', type='bold', task='stopsignal', run='02', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/motion/sub-01_task-stopsignal_run-03_bold.nii.gz.par', type='bold', task='stopsignal', run='03', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/filter_regressor00.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/filter_regressor01.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/filter_regressor02.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/motion_regressor00.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/motion_regressor01.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/noise/motion_regressor02.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/ref/_fs_threshold20/aparc+aseg_thresh_warped_thresh.nii', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/preproc/sub-01/ref/sub-01_task-stopsignal_run-01_bold_roi.nii.gz', type='roi', task='stopsignal', run='01', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/anat/sub-01_inplaneT2.nii.gz', type='inplaneT2', modality='anat', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/anat/sub-01_T1w.nii.gz', type='T1w', modality='anat', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_failedstop_run1_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_failedstop_run2_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_failedstop_run3_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_successfulstop_run1_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_successfulstop_run2_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/EVs/stopsig_successfulstop_run3_evs.txt', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-01_bold.nii.gz', type='bold', task='conditionalstopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-01_events.tsv', type='events', task='conditionalstopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-02_bold.nii.gz', type='bold', task='conditionalstopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-02_events.tsv', type='events', task='conditionalstopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-03_bold.nii.gz', type='bold', task='conditionalstopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-conditionalstopsignal_run-03_events.tsv', type='events', task='conditionalstopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-01_bold.nii.gz', type='bold', task='stopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-01_events.tsv', type='events', task='stopsignal', run='01', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-02_bold.nii.gz', type='bold', task='stopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-02_events.tsv', type='events', task='stopsignal', run='02', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-03_bold.nii.gz', type='bold', task='stopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/sub-01/func/sub-01_task-stopsignal_run-03_events.tsv', type='events', task='stopsignal', run='03', modality='func', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/aparc.annot.a2009s.ctab', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/aparc.annot.ctab', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/aparc.annot.DKTatlas40.ctab', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/BA.ctab', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/BA.thresh.ctab', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.aparc.a2009s.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.aparc.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.aparc.DKTatlas40.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA1.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA1.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA2.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA2.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA3a.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA3a.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA3b.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA3b.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA4a.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA4a.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA4p.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA4p.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA6.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA6.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA44.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA44.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA45.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA45.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.BA.thresh.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.cortex.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.entorhinal_exvivo.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.MT.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.MT.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.perirhinal.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.V1.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.V1.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.V2.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/lh.V2.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.aparc.a2009s.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.aparc.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.aparc.DKTatlas40.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA1.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA1.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA2.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA2.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA3a.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA3a.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA3b.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA3b.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA4a.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA4a.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA4p.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA4p.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA6.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA6.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA44.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA44.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA45.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA45.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.BA.thresh.annot', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.cortex.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.entorhinal_exvivo.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.MT.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.MT.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.perirhinal.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.V1.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.V1.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.V2.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/label/rh.V2.thresh.label', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/.xdebug_mris_calc', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aparc+aseg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aparc.a2009s+aseg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aseg.auto.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aseg.auto_noCCseg.label_intensities.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aseg.auto_noCCseg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/aseg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/brain.finalsurfs.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/brain.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/brainmask.auto.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/brainmask.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/ctrl_pts.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/filled.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/lh.ribbon.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/mri_nu_correct.mni.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/mri_nu_correct.mni.log.bak', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/norm.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/nu.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/nu_noneck.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/orig.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/orig/001.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/orig_nu.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/orig_nu.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/rawavg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/rh.ribbon.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/ribbon.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/segment.dat', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/T1.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/talairach.label_intensities.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/talairach.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/talairach_with_skull.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/talairach_with_skull_2.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/cc_up.lta', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.auto.xfm', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.lta', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.m3z', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.m3z.inv.x.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.m3z.inv.y.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.m3z.inv.z.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach.xfm', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach_avi.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach_avi_QA.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach_with_skull.lta', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talairach_with_skull_2.lta', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/transforms/talsrcimg_to_711-2C_as_mni_average_305_t4_vox2vox.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/wm.asegedit.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/wm.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/wm.seg.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/mri/wmparc.mgz', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/build-stamp.txt', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/csurfdir', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/pctsurfcon.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/pctsurfcon.log.old', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/ponscc.cut.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all-status.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all.cmd', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all.done', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all.env', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all.local-copy', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/scripts/recon-all.log', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/aseg.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.aparc.a2009s.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.aparc.DKTatlas40.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.aparc.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.BA.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.BA.thresh.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.curv.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.entorhinal_exvivo.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/lh.w-g.pct.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.aparc.a2009s.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.aparc.DKTatlas40.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.aparc.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.BA.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.BA.thresh.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.curv.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.entorhinal_exvivo.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/rh.w-g.pct.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/stats/wmparc.stats', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.area', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.area.mid', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.area.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.avg_curv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.curv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.curv.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.defect_borders', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.defect_chull', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.defect_labels', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.inflated', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.inflated.H', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.inflated.K', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.inflated.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.jacobian_white', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.orig', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.orig.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.qsphere.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.BE.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.C.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.FI.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.H.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.K1.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.K2.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.K.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.smoothwm.S.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.sphere', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.sphere.reg', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.sulc', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.thickness', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.volume', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.w-g.pct.mgh', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/lh.white', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.area', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.area.mid', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.area.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.avg_curv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.curv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.curv.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.defect_borders', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.defect_chull', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.defect_labels', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.inflated', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.inflated.H', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.inflated.K', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.inflated.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.jacobian_white', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.orig', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.orig.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.pial', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.qsphere.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.BE.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.C.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.FI.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.H.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.K1.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.K2.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.K.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.nofix', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.smoothwm.S.crv', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.sphere', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.sphere.reg', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.sulc', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.thickness', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.volume', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.w-g.pct.mgh', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/surf/rh.white', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/aparc2aseg.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/aparc.a2009s2aseg.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/asegmerge.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/ca_label.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/ca_normalize.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/ca_register.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/ca_register_inv.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/conform.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/cortical_ribbon.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/em_register.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/fill.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/inorm1.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/inorm2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.aparc2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.aparc.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.aparcstats2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.aparcstats3.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.aparcstats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.avgcurv.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.curvstats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.final_surfaces.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.inflate1.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.inflate2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.jacobian_white.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.pctsurfcon.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.pial_surface.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.qsphere.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.smoothwm1.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.smoothwm2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.sphmorph.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.sphreg.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.surfvolume.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.tessellate.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.topofix.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/lh.white_surface.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/mri_remove_neck.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/nu.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.aparc2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.aparc.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.aparcstats2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.aparcstats3.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.aparcstats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.avgcurv.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.curvstats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.final_surfaces.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.inflate1.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.inflate2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.jacobian_white.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.pctsurfcon.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.pial_surface.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.qsphere.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.smoothwm1.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.smoothwm2.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.sphmorph.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.sphreg.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.surfvolume.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.tessellate.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.topofix.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/rh.white_surface.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/segstats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/skull.lta.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/skull_2.lta.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/skull_strip.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/talairach.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/wmaparc.stats.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/wmaparc.touch', subject='01'),
#  File(filename='/scratch/PSB6351_2017/ds008_R2.0.0/surfaces/sub-01/touch/wmsegment.touch', subject='01')]
